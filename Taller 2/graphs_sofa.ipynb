# %% [markdown]
# ### Taller No. 2 Soft Robotics

# %% [markdown]
# Explicación

# %% [markdown]
# > Importación de librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd 
plt.style.use('classic')

# %% [markdown]
# > Gráficas

# %%
graphs = pd.read_csv('data.csv')
graphs.head(4)
# Out:
#    Pressure         x          y          z
# 0       0.0  6.496067  17.531494  10.613219
# 1    3000.0  6.496067  17.531494  10.613219
# 2    6000.0  6.496067  17.531494  10.613219
# 3    9000.0  6.496075  17.531589  10.614261

# %%
fig, axs = plt.subplots(3, 1, figsize=(8, 12))

axs[0].plot(graphs['Pressure'], graphs['x'], marker='o', linestyle='-', color='blue')
axs[0].set_title('X (mm) vs Presión (Pa)')
axs[0].set_xlabel('Presión (Pa)')
axs[0].set_ylabel('X (mm)')
axs[0].grid()

axs[1].plot(graphs['Pressure'], graphs['y'], marker='o', linestyle='-', color='red')
axs[1].set_title('Y (mm) vs Presión (Pa)')
axs[1].set_xlabel('Presión (Pa)')
axs[1].set_ylabel('Y (mm)')
axs[1].grid()

axs[2].plot(graphs['Pressure'], graphs['z'], marker='o', linestyle='-', color='green')
axs[2].set_title('Z (mm) vs Presión (Pa)')
axs[2].set_xlabel('Presión (Pa)')
axs[2].set_ylabel('Z (mm)')
axs[2].grid()

plt.tight_layout()

plt.show()

# %%
fig = plt.figure(figsize=(15, 9))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(graphs['x'], graphs['y'], graphs['z'], c=graphs['Pressure'], cmap='viridis')
ax.set_xlabel('X (mm)')
ax.set_ylabel('Y (mm)')
ax.set_zlabel('Z (mm)')
ax.set_title(r'$Posición\; de\;la\;punta\;actuador$')

plt.colorbar(sc, label='Pressure (Pa)')

plt.show()
