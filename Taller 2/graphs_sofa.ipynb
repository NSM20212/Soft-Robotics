# %% [markdown]
# ### Taller No. 2 Soft Robotics

# %% [markdown]
# Explicación

# %% [markdown]
# > Importación de librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd 
plt.style.use('classic')

# %% [markdown]
# > Gráficas

# %%
graphs = pd.read_csv('data_1.csv')
graphs2 = pd.read_csv('data_2.csv')
graphs.head(4)
# Out:
#     Pressure         x          y          z
# 0   0.000000  6.496067  17.531494  10.613219
# 1  30.060120  6.496067  17.531494  10.613219
# 2  60.120240  6.496067  17.531494  10.613219
# 3  90.180361  6.496067  17.531494  10.613219

# %%
graphs2.head(4)
# Out:
#     Pressure         x          y          z
# 0   0.000000  6.501182  17.528899  50.561101
# 1  30.060120  6.501182  17.528899  50.561101
# 2  60.120240  6.501182  17.528899  50.561101
# 3  90.180361  6.501182  17.528899  50.561101

# %%
fig, axs = plt.subplots(3, 2, figsize=(12, 12))


# actuador 1

axs[0,0].plot(graphs['Pressure'], graphs['x'], linestyle='-', color='blue')
axs[0,0].set_title('X (mm) vs Presión (Pa) actuador 1')
axs[0,0].set_xlabel('Presión (Pa)')
axs[0,0].set_ylabel('X (mm)')
axs[0,0].grid()

axs[1,0].plot(graphs['Pressure'], graphs['y'], linestyle='-', color='red')
axs[1,0].set_title('Y (mm) vs Presión (Pa) actuador 1')
axs[1,0].set_xlabel('Presión (Pa)')
axs[1,0].set_ylabel('Y (mm)')
axs[1,0].grid()

axs[2,0].plot(graphs['Pressure'], graphs['z'], linestyle='-', color='green')
axs[2,0].set_title('Z (mm) vs Presión (Pa) actuador 1')
axs[2,0].set_xlabel('Presión (Pa)')
axs[2,0].set_ylabel('Z (mm)')
axs[2,0].grid()

# actuador2
axs[0,1].plot(graphs2['Pressure'], graphs2['x'], linestyle='-', color='blue')
axs[0,1].set_title('X (mm) vs Presión (Pa) actuador 2')
axs[0,1].set_xlabel('Presión (Pa)')
axs[0,1].set_ylabel('X (mm)')
axs[0,1].grid()

axs[1,1].plot(graphs2['Pressure'], graphs2['y'], linestyle='-', color='red')
axs[1,1].set_title('Y (mm) vs Presión (Pa) actuador 2')
axs[1,1].set_xlabel('Presión (Pa)')
axs[1,1].set_ylabel('Y (mm)')
axs[1,1].grid()

axs[2,1].plot(graphs2['Pressure'], graphs2['z'], linestyle='-', color='green')
axs[2,1].set_title('Z (mm) vs Presión (Pa) actuador 2')
axs[2,1].set_xlabel('Presión (Pa)')
axs[2,1].set_ylabel('Z (mm)')
axs[2,1].grid()

plt.tight_layout()

plt.savefig('graficas_xyz_actuadores.png')

plt.show()

# %%
fig = plt.figure(figsize=(15, 9))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(graphs['x'], graphs['y'], graphs['z'], c=graphs['Pressure'], cmap='viridis')
ax.set_xlabel('X (mm)')
ax.set_ylabel('Y (mm)')
ax.set_zlabel('Z (mm)')
ax.set_title(r'$Posición\; de\;la\;punta\;actuador\;N_{1}$')

plt.colorbar(sc, label='Pressure (Pa)')
plt.savefig('actuador_1_3D.png')
plt.show()

# %%
fig = plt.figure(figsize=(15, 9))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(graphs2['x'], graphs2['y'], graphs2['z'], c=graphs2['Pressure'], cmap='viridis')
ax.set_xlabel('X (mm)')
ax.set_ylabel('Y (mm)')
ax.set_zlabel('Z (mm)')
ax.set_title(r'$Posición\; de\;la\;punta\;actuador\;N_{2}$')

plt.colorbar(sc, label='Pressure (Pa)')
plt.savefig('actuador_2_3D.png')
plt.show()
